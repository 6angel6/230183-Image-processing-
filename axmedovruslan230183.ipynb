# %% [raw]
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
#
# image = cv2.imread('image.jpeg')
# print(image.shape)
#
# (h, w) = image.shape[:2]

# %%
translation_matrix = np.float32([[1, 0, 100],
                                 [0, 1,  50]])

translated_image = cv2.warpAffine(image, translation_matrix, (w, h))

plt.imshow(cv2.cvtColor(translated_image, cv2.COLOR_BGR2RGB))
plt.title('Translated Image')
plt.axis('off')
plt.show()

print(translated_image.shape)

# %%
translation_matrix = np.float32([[1, 0, -80], [0, 1, -120]])

translation_matrix = np.float32([[1, 0, 0], [0, 1, 200]])

# %%
center = (w // 2, h // 2)

rotation_matrix = cv2.getRotationMatrix2D(center, 45, 1.0)

rotated_image = cv2.warpAffine(image, rotation_matrix, (w, h))

plt.imshow(cv2.cvtColor(rotated_image, cv2.COLOR_BGR2RGB))
plt.title('Rotated Image (45 degrees)')
plt.axis('off')
plt.show()

# %%
rotation_matrix = cv2.getRotationMatrix2D(center, 90, 1.0)

rotation_matrix = cv2.getRotationMatrix2D(center, 180, 1.0)

rotation_matrix = cv2.getRotationMatrix2D(center, 30, 0.7)

rotation_matrix = cv2.getRotationMatrix2D(center, -15, 1.4)

# %%
scale_factor = 2.0
scaling_matrix = cv2.getRotationMatrix2D((0, 0), 0, scale_factor)

# Новый размер изображения
new_w = int(w * scale_factor)
new_h = int(h * scale_factor)

scaled_image = cv2.warpAffine(image, scaling_matrix, (new_w, new_h))

plt.imshow(cv2.cvtColor(scaled_image, cv2.COLOR_BGR2RGB))
plt.title(f'Scaled Image ({scale_factor}x)')
plt.axis('off')
plt.show()

print(scaled_image.shape)

# %%
scale_factor = 0.5
new_w, new_h = int(w * scale_factor), int(h * scale_factor)
scaling_matrix = cv2.getRotationMatrix2D((0, 0), 0, scale_factor)
scaled = cv2.warpAffine(image, scaling_matrix, (new_w, new_h))

scale_x = 1.8
scale_y = 0.6
scaling_matrix = np.float32([[scale_x, 0, 0],
                             [   0, scale_y, 0]])
scaled = cv2.warpAffine(image, scaling_matrix, (int(w*scale_x), int(h*scale_y)))

# %%
shear_factor = 0.67
shearing_matrix = np.float32([[1, shear_factor, 0],
                              [0,           1, 0]])

sheared_image = cv2.warpAffine(image, shearing_matrix, (w, h))

plt.imshow(cv2.cvtColor(sheared_image, cv2.COLOR_BGR2RGB))
plt.title(f'Sheared Image (x-axis, factor {shear_factor})')
plt.axis('off')
plt.show()

# %%
shear_factor_y = 0.4
shearing_y = np.float32([[1,          0, 0],
                         [shear_factor_y, 1, 0]])
sheared_y = cv2.warpAffine(image, shearing_y, (w, h))

shear_x = 0.3
shear_y = -0.5
shear_both = np.float32([[1,     shear_x, 0],
                         [shear_y,     1, 0]])
sheared = cv2.warpAffine(image, shear_both, (w, h))
