# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read an image
image = cv2.imread('trump.jpg')
print(image.shape)

# Negative shifts: move left by 50 pixels, up by 20 pixels
translation_matrix = np.float32([[1, 0, -50], [0, 1, -20]])

# Apply the translation matrix to the image
translated_image = cv2.warpAffine(
    image,
    translation_matrix,
    (
        image.shape[1],
        image.shape[0]
    )
)

print(translated_image.shape)
# Out:
# (251, 201, 3)
# (251, 201, 3)

# %%
plt.imshow(
    cv2.cvtColor
    (
        translated_image,
        cv2.COLOR_BGR2RGB
    )
)

plt.title('Translated Image (Negative Shift)')
plt.axis('off')
plt.show()

# %%
# Positive shifts: move right by 70 pixels, down by 30 pixels
translation_matrix_positive = np.float32([[1, 0, 70], [0, 1, 30]])

# Apply the translation matrix to the image
translated_image_positive = cv2.warpAffine(
    image,
    translation_matrix_positive,
    (
        image.shape[1],
        image.shape[0]
    )
)

print(translated_image_positive.shape)
# Out:
# (251, 201, 3)

# %%
plt.imshow(
    cv2.cvtColor
    (
        translated_image_positive,
        cv2.COLOR_BGR2RGB
    )
)

plt.title('Translated Image (Positive Shift)')
plt.axis('off')
plt.show()

# %%
# rotation
(h, w) = image.shape[:2]

center = (w // 2, h // 2)

# Define a rotation matrix to rotate by 45 degrees
rotation_matrix = cv2.getRotationMatrix2D(center,
45, 1.0)

# Apply the rotation to the image
rotated_image = cv2.warpAffine(image,
rotation_matrix, (w, h))

# Display the rotated image
plt.imshow(cv2.cvtColor(rotated_image,
cv2.COLOR_BGR2RGB))
plt.title('Rotated Image (45 degrees)')
plt.axis('off')
plt.show()

# %%
# rotation
(h, w) = image.shape[:2]

center = (w // 2, h // 2)

# Define a rotation matrix to rotate by 45 degrees
rotation_matrix = cv2.getRotationMatrix2D(center,
90, 1.0)

# Apply the rotation to the image
rotated_image = cv2.warpAffine(image,
rotation_matrix, (w, h))

# Display the rotated image
plt.imshow(cv2.cvtColor(rotated_image,
cv2.COLOR_BGR2RGB))
plt.title('Rotated Image (90 degrees)')
plt.axis('off')
plt.show()

# %%
# rotation
(h, w) = image.shape[:2]

center = (w // 2, h // 2)

# Define a rotation matrix to rotate by 45 degrees
rotation_matrix = cv2.getRotationMatrix2D(center,
180, 1.0)

# Apply the rotation to the image
rotated_image = cv2.warpAffine(image,
rotation_matrix, (w, h))

# Display the rotated image
plt.imshow(cv2.cvtColor(rotated_image,
cv2.COLOR_BGR2RGB))
plt.title('Rotated Image (180 degrees)')
plt.axis('off')
plt.show()

# %%
# scalling
Factor = 2

scaling_matrix = cv2.getRotationMatrix2D(
    (
        0,
        0
    ),
    0,
    Factor
)

# Apply the scaling transformation
scaled_image = cv2.warpAffine(
    image,
    scaling_matrix,
    (
        int(w*Factor),
        int(h*Factor)
    )
)

# Display the scaled image
plt.imshow(cv2.cvtColor(scaled_image,
cv2.COLOR_BGR2RGB))

plt.title('Scaled Image (2x)')
plt.axis('off')
plt.show()

print(scaled_image.shape)
# Out:
# (502, 402, 3)

# %%
# scalling
Factor = 0.5

scaling_matrix = cv2.getRotationMatrix2D(
    (
        0,
        0
    ),
    0,
    Factor
)

# Apply the scaling transformation
scaled_image = cv2.warpAffine(
    image,
    scaling_matrix,
    (
        int(w*Factor),
        int(h*Factor)
    )
)

# Display the scaled image
plt.imshow(cv2.cvtColor(scaled_image,
cv2.COLOR_BGR2RGB))

plt.title('Scaled Image (3x)')
plt.axis('off')
plt.show()

print(scaled_image.shape)
# Out:
# (125, 100, 3)

# %%
# scalling
Factor = 3

scaling_matrix = cv2.getRotationMatrix2D(
    (
        0,
        0
    ),
    0,
    Factor
)

# Apply the scaling transformation
scaled_image = cv2.warpAffine(
    image,
    scaling_matrix,
    (
        int(w*Factor),
        int(h*Factor)
    )
)

# Display the scaled image
plt.imshow(cv2.cvtColor(scaled_image,
cv2.COLOR_BGR2RGB))

plt.title('Scaled Image (3x)')
plt.axis('off')
plt.show()

print(scaled_image.shape)
# Out:
# (753, 603, 3)

# %%
Factor = 5

scaling_matrix = cv2.getRotationMatrix2D(
    (0,
     0),
    0,
    Factor
)

# Apply the scaling transformation
scaled_image_5x = cv2.warpAffine(
    image,
    scaling_matrix,
    (
        int(w * Factor),
        int(h * Factor)
    )
)

# Display the scaled image
plt.imshow(cv2.cvtColor(scaled_image_5x,
                       cv2.COLOR_BGR2RGB))

plt.title('Scaled Image (5x)')
plt.axis('off')
plt.show()

print(f"Scaled image shape: {scaled_image_5x.shape}")

# Save the scaled image
cv2.imwrite('scaled_image_5x.jpeg', scaled_image_5x)
print("Scaled image saved as 'scaled_image_5x.jpeg'")
# Out:
# Scaled image shape: (1255, 1005, 3)
# Scaled image saved as 'scaled_image_5x.jpeg'

# %%
Factor = 8

scaling_matrix = cv2.getRotationMatrix2D(
    (
        0,
        0
    ),
    0,
    Factor
)

# Apply the scaling transformation
scaled_image_8x = cv2.warpAffine(
    image,
    scaling_matrix,
    (
        int(w * Factor),
        int(h * Factor)
    )
)

# Display the scaled image
plt.imshow(cv2.cvtColor(scaled_image_8x,
                       cv2.COLOR_BGR2RGB))

plt.title('Scaled Image (8x)')
plt.axis('off')
plt.show()

print(f"Scaled image shape: {scaled_image_8x.shape}")

# Save the scaled image
cv2.imwrite('scaled_image_8x.jpeg', scaled_image_8x)
print("Scaled image saved as 'scaled_image_8x.jpeg'")
# Out:
# Scaled image shape: (2008, 1608, 3)
# Scaled image saved as 'scaled_image_8x.jpeg'

# %%
Factor = 10

scaling_matrix = cv2.getRotationMatrix2D(
    (
        0,
        0
    ),
    0,
    Factor
)

# Apply the scaling transformation
scaled_image_10x = cv2.warpAffine(
    image,
    scaling_matrix,
    (
        int(w * Factor),
        int(h * Factor)
    )
)

# Display the scaled image
plt.imshow(cv2.cvtColor(scaled_image_10x,
                       cv2.COLOR_BGR2RGB))

plt.title('Scaled Image (10x)')
plt.axis('off')
plt.show()

print(f"Scaled image shape: {scaled_image_10x.shape}")

# Save the scaled image
cv2.imwrite('scaled_image_10x.jpeg', scaled_image_10x)
print("Scaled image saved as 'scaled_image_10x.jpeg'")
# Out:
# Scaled image shape: (2510, 2010, 3)
# Scaled image saved as 'scaled_image_10x.jpeg'

# %%
Factor = 20

scaling_matrix = cv2.getRotationMatrix2D(
    (
        0,
        0
    ),
    0,
    Factor
)

# Apply the scaling transformation
scaled_image_20x = cv2.warpAffine(
    image,
    scaling_matrix,
    (
        int(w * Factor),
        int(h * Factor)
    )
)

# Display the scaled image
plt.imshow(cv2.cvtColor(scaled_image_20x,
                       cv2.COLOR_BGR2RGB))

plt.title('Scaled Image (20x)')
plt.axis('off')
plt.show()

print(f"Scaled image shape: {scaled_image_20x.shape}")

# Save the scaled image
cv2.imwrite('scaled_image_20x.jpeg', scaled_image_20x)
print("Scaled image saved as 'scaled_image_20x.jpeg'")
# Out:
# Scaled image shape: (5020, 4020, 3)
# Scaled image saved as 'scaled_image_20x.jpeg'

# %%
m = 0.67
shearing_matrix = np.float32([[1, m, 0], [0, 1,
0]])
# Apply the shearing transformation
sheared_image = cv2.warpAffine(image,
shearing_matrix, (w, h))
# Display the sheared image
plt.imshow(cv2.cvtColor(sheared_image,
cv2.COLOR_BGR2RGB))
plt.title('Sheared Image (x-axis, factor ' + str(m)
+')')

plt.axis('off')
plt.show()

# %%
m_x_0_3 = 0.3
shearing_matrix_x_0_3 = np.float32([[1, m_x_0_3, 0], [0, 1, 0]])

# Apply the shearing transformation
sheared_image_x_0_3 = cv2.warpAffine(image,
                                     shearing_matrix_x_0_3,
                                     (w, h))

# Display the sheared image
plt.imshow(cv2.cvtColor(sheared_image_x_0_3, cv2.COLOR_BGR2RGB))
plt.title('Sheared Image (x-axis, factor ' + str(m_x_0_3) + ')')
plt.axis('off')
plt.show()

# Save the sheared image
cv2.imwrite('sheared_image_x_0_3.jpeg', sheared_image_x_0_3)
print("Sheared image (x-axis, factor 0.3) saved as 'sheared_image_x_0_3.jpeg'")
# Out:
# Sheared image (x-axis, factor 0.3) saved as 'sheared_image_x_0_3.jpeg'

# %%
m_x_0_7 = 0.7
shearing_matrix_x_0_7 = np.float32([[1, m_x_0_7, 0], [0, 1, 0]])

# Apply the shearing transformation
sheared_image_x_0_7 = cv2.warpAffine(image,
                                     shearing_matrix_x_0_7,
                                     (w, h))

# Display the sheared image
plt.imshow(cv2.cvtColor(sheared_image_x_0_7, cv2.COLOR_BGR2RGB))
plt.title('Sheared Image (x-axis, factor ' + str(m_x_0_7) + ')')
plt.axis('off')
plt.show()

# Save the sheared image
cv2.imwrite('sheared_image_x_0_7.jpeg', sheared_image_x_0_7)
print("Sheared image (x-axis, factor 0.7) saved as 'sheared_image_x_0_7.jpeg'")
# Out:
# Sheared image (x-axis, factor 0.7) saved as 'sheared_image_x_0_7.jpeg'

# %%
m_y_0_3 = 0.3
shearing_matrix_y_0_3 = np.float32([[1, 0, 0], [m_y_0_3, 1, 0]])

# Apply the shearing transformation
sheared_image_y_0_3 = cv2.warpAffine(image,
                                     shearing_matrix_y_0_3,
                                     (w, h))

# Display the sheared image
plt.imshow(cv2.cvtColor(sheared_image_y_0_3, cv2.COLOR_BGR2RGB))
plt.title('Sheared Image (y-axis, factor ' + str(m_y_0_3) + ')')
plt.axis('off')
plt.show()

# Save the sheared image
cv2.imwrite('sheared_image_y_0_3.jpeg', sheared_image_y_0_3)
print("Sheared image (y-axis, factor 0.3) saved as 'sheared_image_y_0_3.jpeg'")
# Out:
# Sheared image (y-axis, factor 0.3) saved as 'sheared_image_y_0_3.jpeg'

# %%
m_y_0_7 = 0.7
shearing_matrix_y_0_7 = np.float32([[1, 0, 0], [m_y_0_7, 1, 0]])

# Apply the shearing transformation
sheared_image_y_0_7 = cv2.warpAffine(image,
                                     shearing_matrix_y_0_7,
                                     (w, h))

# Display the sheared image
plt.imshow(cv2.cvtColor(sheared_image_y_0_7, cv2.COLOR_BGR2RGB))
plt.title('Sheared Image (y-axis, factor ' + str(m_y_0_7) + ')')
plt.axis('off')
plt.show()

# Save the sheared image
cv2.imwrite('sheared_image_y_0_7.jpeg', sheared_image_y_0_7)
print("Sheared image (y-axis, factor 0.7) saved as 'sheared_image_y_0_7.jpeg'")
# Out:
# Sheared image (y-axis, factor 0.7) saved as 'sheared_image_y_0_7.jpeg'
